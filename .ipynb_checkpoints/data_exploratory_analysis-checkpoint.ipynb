# %%
import numpy as np
import pandas as pd
from pandas.api.types import is_numeric_dtype
import math
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Functions

# %%
def extract_month(value):
    return value.split("/")[0]

# %%
def gender_generalize(gender:[str], replace_nan:[str] = "---"):
    """changes the genders to female if f in str, else male. if gender = nan returns ---"""
    if type(gender) != str:
        return replace_nan
    if "f" in gender.lower():
        return "female"
    else:
        return "male"

# %%
def split_df_in_numeric_categ_dfs(this_df):
    """takes in a dataframe, finds numerical (float, int) and categorical and returns them as tuple (num_df, cat_df)"""
    numer_lst = [_ for _ in this_df.select_dtypes(include=['int','float']).dtypes.index]
    cat_lst = [_ for _ in this_df.select_dtypes(exclude=['int','float']).dtypes.index]
    return (this_df[numer_lst], this_df[cat_lst])

# %%
def list_numeric_categ_columns_in_df(this_df):
    """takes in a dataframe, finds numerical (float, int) and categorical columns and returns them as tuple of lists 
       (numer_col_lst, cat_col_df_lst)"""
    numer_col_lst = [_ for _ in this_df.select_dtypes(include=['int','float']).dtypes.index]
    cat_col_lst = [_ for _ in this_df.select_dtypes(exclude=['int','float']).dtypes.index]
    return (numer_col_lst, cat_col_lst)

# %%
def lowercase_underscore_column_names(this_df):
    """changes all columnnames to lower case and replace space with underscore"""
    for col in this_df.columns:
        this_df.rename(columns={col:col.lower().replace(" ", "_")}, inplace=True)

# %%
def all_numeric_to_int(this_df):
    for col in split_df_in_numeric_categ_dfs(this_df)[0]:
        this_df[col] = this_df[col].astype(np.int64)

# %%
def distrib_plots(num_df):
    """creates plot for every column, checks column is numerical and automatically adjusts the grid matrix"""
    matrix_size = math.ceil(len(num_df)**0.5)
    plt.figure(figsize = (14,12))
    for i, col in enumerate(num_df.columns, 1):
        if is_numeric_dtype(num_df[col]):
            plt.subplot(3,3,i)
            sns.distplot(num_df[col], kde=True)

# %%
def distribution_plots(num_df):   # not nice, no grid
    for col in num_df.columns[1:]:
        sns.displot(num_df, x=col, kde=True)

# %%
def hist_plots(num_df):
    """creates plot for every column, checks column is numerical and automatically adjusts the grid matrix"""
    matrix_size = math.ceil(len(num_df)**0.5)   # create square matrix according to number of columns 
    plt.figure(figsize = (14,12))
    for i, col in enumerate(num_df.columns, 1):
        if is_numeric_dtype(num_df[col]):
            plt.subplot(3,3,i)
            sns.histplot(num_df[col], kde=True)

# %%
def heat_map(num_df):
    corr = num_df.corr()
    mask = np.zeros_like(corr)
    mask[np.triu_indices_from(mask)] = True
    with sns.axes_style("white"):
        f, ax = plt.subplots(figsize=(9, 7))
        ax = sns.heatmap(corr, mask=mask,cmap='coolwarm', vmin=-1,vmax=1,annot=True, square=True)

# %%
def remove_index_column(this_df):
    """checks and if apllicable removes "Unnamed: 0"-column which might be in file when csv saving was done with index"""
    for _ in this_df.columns:
        if _[:7] == "unnamed":
            this_df = this_df.drop(this_df.columns[0],axis=1,inplace=True)

# %%
# TODO: numerical vs numerical and choice bin number and names
def plot_rate_by(this_df, group_by_what:[str] = None, rate_by:[str] = None, num_bins:[int] = 5):
    """plots two columns against each other with bar plots (2 categorical columns) or count plot (numerical vs categorical),
       num_bin adjusts number of bin if numerical bin is used as group_by_what value (create categorical values)"""
    if this_df is None:
        return "DataFrame is empty"
    if group_by_what in this_df.columns and rate_by in this_df.columns:
        fig, ax = plt.subplots(figsize = (12,8))
        ax.set_title(f"{group_by_what.capitalize().replace('_', ' ')} by {rate_by.capitalize().replace('_', ' ')}", size="18", fontweight="bold")
        if group_by_what in split_df_in_numeric_categ_dfs(this_df)[1]:
            groupby_df = pd.DataFrame({'count':this_df.groupby([group_by_what,rate_by]).size()}).reset_index()
            sns.barplot(x=groupby_df[group_by_what],y=groupby_df["count"], hue=groupby_df[rate_by], ax=ax, palette="YlOrRd")
        else:
            bin_limits = np.linspace(np.min(this_df[group_by_what]),np.max(this_df[group_by_what]),num_bins)
            bin_labels = [f" ≤ {_}" for _ in np.round(bin_limits, 2)[1:len(bin_limits)]]
            num_bins = pd.cut(this_df[group_by_what],bins=bin_limits,labels=bin_labels)#["low","medium low","medium high","high"])
            sns.countplot(x = num_bins,y = None, hue=this_df[rate_by], palette="YlOrRd")
            if len(num_bins) > 7:
                plt.xticks(rotation=90)
        plt.legend(loc="upper right")
    else:
        return "check column names"

# %%
def plot_rate_by2(this_df, group_by_what:[str] = None, rate_by:[str] = None, num_bins:[int] = 5):
    """plots two columns against each other with bar plots (2 categorical columns) or count plot (numerical vs categorical),
       num_bin adjusts number of bin if numerical bin is used as group_by_what value (create categorical values)"""
    if this_df is None:
        return "DataFrame is empty"
    if group_by_what in this_df.columns and rate_by in this_df.columns:
        fig, ax = plt.subplots(figsize = (12,8))
        ax.set_title(f"{group_by_what.capitalize().replace('_', ' ')} by {rate_by.capitalize().replace('_', ' ')}", size="18", fontweight="bold")
        if group_by_what in list_numeric_categ_columns_in_df(this_df)[1]:
            groupby_df = pd.DataFrame({'count':this_df.groupby([group_by_what,rate_by]).size()}).reset_index()
            sns.barplot(x=groupby_df[group_by_what],y=groupby_df["count"], hue=groupby_df[rate_by], ax=ax, palette="YlOrRd")
        else:
            bin_limits = np.linspace(np.min(this_df[group_by_what]),np.max(this_df[group_by_what]),num_bins)
            bin_labels = [f" ≤ {_}" for _ in np.round(bin_limits, 2)[1:len(bin_limits)]]
            num_bins = pd.cut(this_df[group_by_what],bins=bin_limits,labels=bin_labels)#["low","medium low","medium high","high"])
            sns.countplot(x = num_bins,y = None, hue=this_df[rate_by], palette="YlOrRd")
            if len(bin_labels) > 7:
                plt.xticks(rotation=90)
        plt.legend(loc="upper right")
        
    else:
        return "check column names"

# %%
plot_rate_by2(raw_df, group_by_what = "income", rate_by ="response", num_bins=9)

# %% [markdown]
# ## Read & Clean - Data_Marketing_Customer_Analysis_Round2.csv

# %%
raw_df = pd.read_csv("C:/Users/roman/Documents/GitHub/Customer_Data_Analysis/Data/Data_Marketing_Customer_Analysis_Round2.csv")

# %%
lowercase_underscore_column_names(raw_df)

# %%
remove_index_column(raw_df)

# %%
# extract the month of the effective_to_date column
raw_df["month"] = list(map(extract_month,(raw_df["effective_to_date"])))

# %%
# create df and select onyl the first quarter (month 1-3)
selected_df = raw_df.loc[np.int64(raw_df['month']) < 4]

# %%
# selected_df.describe()

# %%
# selected_df.info()

# %% [markdown]
# ## EDA

# %%
distribution_plots(split_df_in_numeric_categ_dfs(raw_df)[0])

# %%
distrib_plots(split_df_in_numeric_categ_dfs(raw_df)[0])
# Out:
# C:\Users\roman\Python\anaconda\envs\DA_Env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\roman\Python\anaconda\envs\DA_Env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
hist_plots(split_df_in_numeric_categ_dfs(raw_df)[0])

# %% [markdown]
# #### Total Response

# %%
sns.countplot(x=raw_df["response"])
# Out:
# <AxesSubplot:xlabel='response', ylabel='count'>

# %%
raw_df['response'].value_counts(normalize=True)
# Out:
# No     0.857379
# Yes    0.142621
# Name: response, dtype: float64

# %%
print(f"""The response rate was
    {round(raw_df['response'].value_counts(normalize=True)[0], 2)} % {raw_df['response'].value_counts(normalize=True).index[0]} and 
    {round(raw_df['response'].value_counts(normalize=True)[1], 2)} % {raw_df['response'].value_counts(normalize=True).index[1]}.""")
# Out:
# The response rate was
#     0.86 % No and
#     0.14 % Yes.

# %%
plot_rate_by(raw_df, "response", "sales_channel")

# %%
plot_rate_by(raw_df, "sales_channel", "response")

# %%
plot_rate_by(raw_df, "total_claim_amount", "response")
# Out:
# [9.90070000e-02 7.23384175e+02 1.44666934e+03 2.16995451e+03
#  2.89323968e+03]

# %%
plot_rate_by(raw_df, "income", "response")

# %%
plot_rate_by(raw_df, "monthly_premium_auto", "response")

# %%
heat_map(raw_df)

# %%
################### file1 file2 file3##################

# %%
new_df = pd.read_csv("C:/users/roman/documents/tester.csv", index_col=False)

# %%
lowercase_underscore_column_names(new_df)
#new_df = new_df.drop("unnamed:_0",axis=1)

# %%
new_nu = split_df_in_numeric_categ_dfs(new_df)[0]

# %%
hist_plots(new_nu)

# %%
heat_map(new_nu)

# %%
plot_rate_by(new_nu, "income", "number_of_open_complaints")
